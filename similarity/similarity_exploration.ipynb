# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore
import pandas as pd

# %%
# Use a service account
cred = credentials.Certificate("secret.json")
firebase_admin.initialize_app(cred)

db = firestore.client()

# Read data
courses_ref = db.collection(u'Courses')
docs = courses_ref.stream()
for doc in docs:
    print(f'{doc.id} => {doc.to_dict()}')
# Out:
# CSCE 110 => {'Course Id': 110, 'Course Other Hours (l)': -1, 'Course Lab Hours (u)': 2, 'Course Name': 'Programming I', 'Course Description': 'Basic concepts in using computation to enhance problem solving abilities; understanding how people communicate with computers, and how computing affects society; computational thinking; representation of data; analysis of program behavior; methods for identifying and fixing errors in programs; understanding abilities and limitation of programs; development and execution of programs.', 'Course Other Hours (u)': -1, 'Course Credit Hours (u)': 4, 'Course Credit Hours (l)': 4, 'Course Lecture Hours (u)': 3, 'Course Lecture Hours (l)': 3, 'Course Lab Hours (l)': 2}
# CSCE 111 => {'Course Id': 111, 'Course Lecture Hours (u)': 3, 'Course Other Hours (u)': -1, 'Course Other Hours (l)': -1, 'Course Lecture Hours (l)': 3, 'Course Description': 'Computation to enhance problem solving abilities; understanding how people communicate with computers, and how computing affects society; computational thinking; software design principles, including algorithm design, data representation, abstraction, modularity, structured and object oriented programming, documentation, testing, portability, and maintenance; understanding programs’ abilities and limitations; development and execution programs.', 'Course Lab Hours (l)': 2, 'Course Lab Hours (u)': 2, 'Course Credit Hours (l)': 4, 'Course Credit Hours (u)': 4, 'Course Name': 'Introduction to Computer Science Concepts and Programming'}
# CSCE 120 => {'Course Lab Hours (u)': 1, 'Course Other Hours (u)': -1, 'Course Description': 'Extend prior programming knowledge to create computer programs that solve problems; use the C++ language; apply computational thinking to enhance problem solving; analyze, design and implement computer programs; use basic and aggregate data types to develop functional and object oriented solutions; develop classes that use dynamic memory and avoid memory leaks; learn error handling strategies to develop more secure and robust programs. Prerequisite: Grade of C or better in ENGR\xa0102, CSCE\xa0110, CSCE\xa0111, or CSCE\xa0206, or equivalent.', 'Course Credit Hours (l)': 3, 'Course Name': 'Program Design and Concepts', 'Course Lecture Hours (l)': 3, 'Course Lab Hours (l)': 1, 'Course Lecture Hours (u)': 3, 'Course Credit Hours (u)': 3, 'Course Other Hours (l)': -1}
# CSCE 121 => {'Course Lecture Hours (u)': 3, 'Course Other Hours (u)': -1, 'Course Other Hours (l)': -1, 'Course Description': 'Computation to enhance problem solving abilities; computational thinking; understanding how people communicate with computers, how computing affects society; design and implementation of algorithms; data types, program control, iteration, functions, classes, and exceptions; understanding abstraction, modularity, code reuse, debugging, maintenance, and other aspects of software development; development and execution of programs. Prerequisite: Programming course (high school or college).', 'Course Lecture Hours (l)': 3, 'Course Lab Hours (l)': 2, 'Course Credit Hours (l)': 4, 'Course Lab Hours (u)': 2, 'Course Credit Hours (u)': 4, 'Course Name': 'Introduction to Program Design and Concepts'}
# CSCE 181 => {'Course Description': 'Introduction to the broad field of computing; presentations from industry and academia about how computer science concepts are used in research and end products; includes a major writing component.', 'Course Name': 'Introduction to Computing', 'Course Lecture Hours (u)': 1, 'Course Other Hours (u)': -1, 'Course Credit Hours (u)': 1, 'Course Lecture Hours (l)': 1, 'Course Lab Hours (l)': -1, 'Course Other Hours (l)': -1, 'Course Lab Hours (u)': -1, 'Course Credit Hours (l)': 1}
# CSCE 201 => {'Course Lab Hours (u)': -1, 'Course Other Hours (l)': -1, 'Course Credit Hours (u)': 3, 'Course Name': 'Fundamentals of Cybersecurity', 'Course Lecture Hours (u)': 3, 'Course Credit Hours (l)': 3, 'Course Description': 'Basic terminology, concepts, technology, and trends of cybersecurity; foundations of cybersecurity to include cryptography, public key infrastructure, standards and protocols, physical security, network fundamentals; workings of systems, networks, infrastructure; legal and ethical issues in cybersecurity. Cross Listing: CYBR\xa0201/CSCE\xa0201.', 'Course Other Hours (u)': -1, 'Course Lecture Hours (l)': 3, 'Course Lab Hours (l)': -1}
# CSCE 206 => {'Course Lecture Hours (u)': 3, 'Course Other Hours (u)': -1, 'Course Other Hours (l)': -1, 'Course Description': '(COSC 1420) Structured Programming in C.   Basic concepts, nomenclature and historical perspective of computers and computing; internal representation of data; software design principles and practice; structured and object-oriented programming in C; use of terminals, operation of editors and executions of student-written programs.', 'Course Lecture Hours (l)': 3, 'Course Lab Hours (l)': 2, 'Course Credit Hours (l)': 4, 'Course Lab Hours (u)': 2, 'Course Credit Hours (u)': 4, 'Course Name': 'Structured Programming in C'}
# CSCE 221 => {'Course Name': 'Data Structures and Algorithms', 'Course Lecture Hours (u)': 3, 'Course Other Hours (l)': -1, 'Course Description': 'Specification and implementation of basic abstract data types and their associated algorithms including stacks, queues, lists, sorting and selection, searching, graphs, and hashing; performance tradeoffs of different implementations and asymptotic analysis of running time and memory usage; includes the execution of student programs written in C++. Prerequisite: CSCE 113 or CSCE\xa0121; CSCE\xa0222/ECEN\xa0222 or ECEN\xa0222/CSCE\xa0222, or concurrent enrollment.', 'Course Lecture Hours (l)': 3, 'Course Other Hours (u)': -1, 'Course Lab Hours (u)': 2, 'Course Lab Hours (l)': 2, 'Course Credit Hours (u)': 4, 'Course Credit Hours (l)': 4}
# CSCE 222 => {'Course Lab Hours (u)': -1, 'Course Other Hours (l)': -1, 'Course Credit Hours (u)': 3, 'Course Name': 'Discrete Structures for Computing', 'Course Credit Hours (l)': 3, 'Course Lecture Hours (u)': 3, 'Course Description': 'Provide mathematical foundations from discrete mathematics for analyzing computer algorithms, for both correctness and performance; introduction to models of computation, including finite state machines and Turing machines. Prerequisite: MATH\xa0151. Cross Listing: ECEN\xa0222/CSCE\xa0222.', 'Course Other Hours (u)': -1, 'Course Lecture Hours (l)': 3, 'Course Lab Hours (l)': -1}
# CSCE 285 => {'Course Lecture Hours (u)': 4, 'Course Other Hours (u)': -1, 'Course Other Hours (l)': -1, 'Course Lecture Hours (l)': 0, 'Course Description': 'Special project in computer science; project must be approved by the department. Prerequisite: Approval of department head; also taught at Galveston campus.', 'Course Lab Hours (l)': -1, 'Course Credit Hours (l)': 0, 'Course Lab Hours (u)': -1, 'Course Credit Hours (u)': 4, 'Course Name': 'Directed Studies'}
# CSCE 289 => {'Course Lab Hours (l)': -1, 'Course Name': 'Special Topics in...', 'Course Lecture Hours (u)': 4, 'Course Credit Hours (l)': 1, 'Course Credit Hours (u)': 4, 'Course Description': 'Selected topics in an identified area of computer science. May be repeated for credit. Prerequisite: Approval of instructor.', 'Course Other Hours (l)': -1, 'Course Lecture Hours (l)': 1, 'Course Lab Hours (u)': -1, 'Course Other Hours (u)': -1}
# CSCE 291 => {'Course Description': 'Research conducted under the direction of faculty member in computer science. May be taken three times for credit. Prerequisites: Freshman or sophomore classification and approval of instructor.', 'Course Name': 'Research', 'Course Lecture Hours (l)': -1, 'Course Credit Hours (u)': 4, 'Course Lecture Hours (u)': -1, 'Course Other Hours (u)': 4, 'Course Lab Hours (l)': -1, 'Course Other Hours (l)': 0, 'Course Lab Hours (u)': -1, 'Course Credit Hours (l)': 0}
# CSCE 305 => {'Course Other Hours (l)': -1, 'Course Lab Hours (u)': -1, 'Course Name': 'Computational Data Science', 'Course Description': 'Computational practice of data science through a sequence of interactive modules that provides an integrated hands-on approach to its methods, tools, applications and supporting technologies including high performance and cloud computing platforms. Prerequisites: Grade of C or better in ENGR\xa0102 or prior programming experience; grade of C or better in MATH\xa0251, MATH\xa0253, or STAT\xa0211; junior or senior classification. Cross Listing: ECEN\xa0360 and STAT\xa0315.', 'Course Lecture Hours (u)': 3, 'Course Other Hours (u)': -1, 'Course Credit Hours (l)': 3, 'Course Credit Hours (u)': 3, 'Course Lab Hours (l)': -1, 'Course Lecture Hours (l)': 3}
# CSCE 310 => {'Course Other Hours (u)': -1, 'Course Lecture Hours (u)': 3, 'Course Credit Hours (l)': 3, 'Course Credit Hours (u)': 3, 'Course Lab Hours (l)': -1, 'Course Other Hours (l)': -1, 'Course Lab Hours (u)': -1, 'Course Description': 'File structures and access methods; database modeling, design and user interface; components of database management systems; information storage and retrieval, query languages, high-level language interface with database systems. Prerequisites: CSCE\xa0221 with a grade of C or better; junior or senior classification.', 'Course Lecture Hours (l)': 3, 'Course Name': 'Database Systems'}
# CSCE 312 => {'Course Lecture Hours (u)': 3, 'Course Other Hours (u)': -1, 'Course Other Hours (l)': -1, 'Course Description': "Introduction to computer systems from programmer's perspective including simple logic design, data representation and processor architecture, programming of processors, memory, control flow, input/output, and performance measurements; hands-on lab assignments. Prerequisites: Grade of C or better in CSCE\xa0221, or concurrent enrollment; or approval of instructor.", 'Course Lecture Hours (l)': 3, 'Course Lab Hours (l)': 2, 'Course Credit Hours (l)': 4, 'Course Lab Hours (u)': 2, 'Course Credit Hours (u)': 4, 'Course Name': 'Computer Organization'}
# CSCE 313 => {'Course Lab Hours (u)': 2, 'Course Other Hours (u)': -1, 'Course Description': 'Introduction to system support for application programs, both on single node and over network including OS application interface, inter-process communication, introduction to system and network programming, and simple computer security concepts; hands-on lab assignments. Prerequisite: CSCE\xa0221 with a grade of C or better; CSCE\xa0312 or corequisite CSCE\xa0350/ECEN\xa0350.', 'Course Lecture Hours (l)': 3, 'Course Credit Hours (l)': 4, 'Course Name': 'Introduction to Computer Systems', 'Course Lab Hours (l)': 2, 'Course Lecture Hours (u)': 3, 'Course Credit Hours (u)': 4, 'Course Other Hours (l)': -1}
# CSCE 314 => {'Course Description': 'Exploration of the design space of programming languages via an in-depth study of two programming languages, one functional and one object-oriented; focuses on idiomatic uses of each language and on features characteristic for each language. Prerequisites: Grade of C or better in CSCE\xa0221, or concurrent enrollment; or approval of instructor.', 'Course Lab Hours (l)': -1, 'Course Other Hours (l)': -1, 'Course Lecture Hours (l)': 3, 'Course Lab Hours (u)': -1, 'Course Name': 'Programming Languages', 'Course Lecture Hours (u)': 3, 'Course Credit Hours (u)': 3, 'Course Credit Hours (l)': 3, 'Course Other Hours (u)': -1}
# CSCE 315 => {'Course Lecture Hours (u)': 2, 'Course Other Hours (u)': -1, 'Course Other Hours (l)': -1, 'Course Description': 'Intensive programming experience that integrates core concepts in Computer Science and familiarizes with a variety of programming/development tools and techniques; students work on 2 or 3 month-long projects each emphasizing a different specialization within Computer Science; focuses on programming techniques to ease code integration, reusability, and clarity. Prerequisites: CSCE\xa0312 and CSCE\xa0314; or CSCE\xa0350/ECEN\xa0350. Corequisite: CSCE\xa0313.', 'Course Lecture Hours (l)': 2, 'Course Lab Hours (l)': 2, 'Course Credit Hours (l)': 3, 'Course Lab Hours (u)': 2, 'Course Credit Hours (u)': 3, 'Course Name': 'Programming Studio'}
# CSCE 320 => {'Course Other Hours (l)': -1, 'Course Lab Hours (u)': -1, 'Course Credit Hours (u)': 3, 'Course Name': 'Principles of Data Science', 'Course Credit Hours (l)': 3, 'Course Lecture Hours (u)': 3, 'Course Description': 'Theoretical foundations, algorithms and methods of deriving valuable insights from data; includes foundations in managing and analyzing data at scale, e.g. big data; data mining techniques and algorithms; exploratory data analysis; statistical methods and models; data visualization. Prerequisites: STAT\xa0211 or ECEN\xa0303; STAT\xa0212 or CSCE\xa0222/ECEN\xa0222. Cross Listing: STAT\xa0335/CSCE\xa0320.', 'Course Other Hours (u)': -1, 'Course Lecture Hours (l)': 3, 'Course Lab Hours (l)': -1}
# CSCE 331 => {'Course Other Hours (l)': -1, 'Course Lab Hours (u)': 2, 'Course Description': 'Intensive programming experience that provides the fundamentals needed for larger-scale software development; integration of concepts in computer science and familiarization with a variety of programming and development tools and techniques; team projects each emphasizing a different specialization within computer science; emphasis on programming techniques to ease code integration and clarity. Prerequisite: CSCE\xa0314, CSCE\xa0350/ECEN\xa0350, or ECEN\xa0350/CSCE\xa0350; concurrent enrollment in CSCE\xa0313.', 'Course Name': 'Foundations of Software Engineering', 'Course Other Hours (u)': -1, 'Course Lecture Hours (u)': 3, 'Course Credit Hours (l)': 4, 'Course Credit Hours (u)': 4, 'Course Lecture Hours (l)': 3, 'Course Lab Hours (l)': 2}
# CSCE 350 => {'Course Lab Hours (u)': 3, 'Course Other Hours (l)': -1, 'Course Credit Hours (u)': 4, 'Course Name': 'Computer Architecture and Design', 'Course Lecture Hours (u)': 3, 'Course Credit Hours (l)': 4, 'Course Description': 'Computer architecture and design; use of register transfer languages and simulation tools to describe and simulate computer operation; central processing unit organization, microprogramming, input/output and memory system architectures. Prerequisites: Grade of C or better in ECEN\xa0248; junior or senior classification. Cross Listing: ECEN\xa0350/CSCE\xa0350.', 'Course Other Hours (u)': -1, 'Course Lecture Hours (l)': 3, 'Course Lab Hours (l)': 3}
# CSCE 399 => {'Course Other Hours (l)': 0, 'Course Lab Hours (u)': -1, 'Course Name': 'High-Impact Experience', 'Course Description': 'Participation in an approved high-impact learning practice; documentation and self-assessment of learning experience. Prerequisite: Junior or senior classification.', 'Course Other Hours (u)': 0, 'Course Credit Hours (l)': 0, 'Course Lecture Hours (u)': -1, 'Course Credit Hours (u)': 0, 'Course Lab Hours (l)': -1, 'Course Lecture Hours (l)': -1}
# CSCE 402 => {'Course Other Hours (l)': -1, 'Course Credit Hours (l)': 3, 'Course Lab Hours (u)': -1, 'Course Other Hours (u)': -1, 'Course Credit Hours (u)': 3, 'Course Description': 'Examination of law and policy issues related to cybersecurity for the spectrum of cybersecurity jobs; includes procurement, operations and maintenance, governance and oversight, protection and defense, analysis, intelligence collection and operation and investigation cybersecurity jobs. Prerequisites: Junior or senior classification; MARA-403 taught at Galveston campus. Cross Listing: MARA\xa0403/CSCE\xa0402.', 'Course Lecture Hours (l)': 3, 'Course Name': 'Law and Policy in Cybersecurity', 'Course Lab Hours (l)': -1, 'Course Lecture Hours (u)': 3}
# CSCE 410 => {'Course Other Hours (u)': -1, 'Course Lecture Hours (u)': 3, 'Course Credit Hours (l)': 3, 'Course Credit Hours (u)': 3, 'Course Lab Hours (l)': -1, 'Course Other Hours (l)': -1, 'Course Lab Hours (u)': -1, 'Course Description': 'Hardware/software evolution leading to contemporary operating systems; basic operating systems concepts; methods of operating systems design and construction including algorithms for CPU scheduling, memory and general resource allocation, process coordination and management; case studies of several operating systems. Prerequisites: CSCE\xa0313 and CSCE\xa0315.', 'Course Lecture Hours (l)': 3, 'Course Name': 'Operating Systems'}
# CSCE 411 => {'Course Lecture Hours (u)': 3, 'Course Other Hours (u)': -1, 'Course Other Hours (l)': -1, 'Course Description': 'Study of computer algorithms for numeric and non-numeric problems; design paradigms; analysis of time and space requirements of algorithms; correctness of algorithms; NP-completeness and undecidability of problems. Prerequisite: Grade of C or better in CSCE\xa0221 and CSCE\xa0222/ECEN\xa0222; junior or senior classification or approval of instructor.', 'Course Lecture Hours (l)': 3, 'Course Lab Hours (l)': -1, 'Course Lab Hours (u)': -1, 'Course Credit Hours (l)': 3, 'Course Credit Hours (u)': 3, 'Course Name': 'Design and Analysis of Algorithms'}
# CSCE 412 => {'Course Lab Hours (l)': -1, 'Course Name': 'Cloud Computing', 'Course Lecture Hours (u)': 3, 'Course Credit Hours (l)': 3, 'Course Credit Hours (u)': 3, 'Course Description': 'Operating system and distributed systems fields that form the basis of cloud computing such as virtualization, key-value storage solutions, group membership, failure detection, peer to peer systems, datacenter networking, resource management and scalability; popular frameworks such as MapReduce and HDFS and cases studies on failure determination. Prerequisite: Grade of C or better in CSCE\xa0315.', 'Course Lecture Hours (l)': 3, 'Course Other Hours (l)': -1, 'Course Lab Hours (u)': -1, 'Course Other Hours (u)': -1}
# CSCE 413 => {'Course Lab Hours (u)': -1, 'Course Other Hours (u)': -1, 'Course Description': 'Basic principles of design and implementation of defect-free software, code reviews including tool-assisted review by static and dynamic analysis, risk analysis and management and methods for software security testing. Prerequisites: Grade of C or better in CSCE\xa0315 or approval of instructor.', 'Course Lecture Hours (l)': 3, 'Course Name': 'Software Security', 'Course Credit Hours (l)': 3, 'Course Lecture Hours (u)': 3, 'Course Lab Hours (l)': -1, 'Course Credit Hours (u)': 3, 'Course Other Hours (l)': -1}
# CSCE 416 => {'Course Other Hours (l)': -1, 'Course Lab Hours (u)': -1, 'Course Credit Hours (l)': 3, 'Course Credit Hours (u)': 3, 'Course Other Hours (u)': -1, 'Course Description': 'Hardware functional verification; case studies on verification in integrated circuit design; introduction to industry best practices; introduction to logic functional verification. Prerequisites: CSCE\xa0312, CSCE\xa0350/ECEN\xa0350, or ECEN\xa0350/CSCE\xa0350, or equivalent in computer architecture; familiarity with C/C++/Verilog/VHDL programming. Cross Listing: ECEN\xa0416/CSCE\xa0416.', 'Course Lecture Hours (l)': 3, 'Course Name': 'Hardware Design Verification', 'Course Lecture Hours (u)': 3, 'Course Lab Hours (l)': -1}
# CSCE 420 => {'Course Lab Hours (u)': -1, 'Course Other Hours (u)': -1, 'Course Description': 'Fundamental concepts and techniques of intelligent systems; representation and interpretation of knowledge on a computer; search strategies and control; active research areas and applications such as notational systems, natural language understanding, vision systems, planning algorithms, intelligent agents and expert systems. Prerequisite: CSCE\xa0411 or approval of instructor.', 'Course Credit Hours (l)': 3, 'Course Name': 'Artificial Intelligence', 'Course Lecture Hours (l)': 3, 'Course Lab Hours (l)': -1, 'Course Lecture Hours (u)': 3, 'Course Credit Hours (u)': 3, 'Course Other Hours (l)': -1}
# CSCE 421 => {'Course Other Hours (l)': -1, 'Course Credit Hours (l)': 3, 'Course Lab Hours (u)': -1, 'Course Other Hours (u)': -1, 'Course Credit Hours (u)': 3, 'Course Description': 'Theoretical foundations of machine learning, pattern recognition and generating predictive models and classifiers from data; includes methods for supervised and unsupervised learning (decision trees, linear discriminants, neural networks, Gaussian models, non-parametric models, clustering, dimensionality reduction, deep learning), optimization procedures and statistical inference. Prerequisite: Grade of C or better in MATH\xa0304, MATH\xa0311, or MATH\xa0323; grade of C or better in STAT\xa0211; grade of C or better in CSCE\xa0221 or STAT\xa0404. Cross Listing: STAT\xa0421/CSCE\xa0421.', 'Course Lecture Hours (l)': 3, 'Course Name': 'Machine Learning', 'Course Lecture Hours (u)': 3, 'Course Lab Hours (l)': -1}
# CSCE 426 => {'Course Lab Hours (l)': -1, 'Course Name': 'Security of Embedded Systems', 'Course Lecture Hours (u)': 3, 'Course Credit Hours (l)': 3, 'Course Credit Hours (u)': 3, 'Course Description': 'Security principles; common security features and flaws in day-to-day embedded systems; security analysis, vulnerability exploits and security fixes for embedded systems. Prerequisite: Grade of C or better in ECEN\xa0350/CSCE\xa0350, CSCE\xa0350/ECEN\xa0350, or CSCE\xa0312; junior or senior classification. Cross Listing: ECEN\xa0426/CSCE\xa0426.', 'Course Other Hours (l)': -1, 'Course Lecture Hours (l)': 3, 'Course Lab Hours (u)': -1, 'Course Other Hours (u)': -1}
# CSCE 429 => {'Course Other Hours (u)': -1, 'Course Lecture Hours (u)': 3, 'Course Credit Hours (l)': 3, 'Course Credit Hours (u)': 3, 'Course Lab Hours (l)': -1, 'Course Other Hours (l)': -1, 'Course Lab Hours (u)': -1, 'Course Description': 'Software development cycle; software outsourcing model, execution and practices; software industries on products, services and consultancy; software globalization; and offshore development culture; travel abroad required. Prerequisite: CSCE\xa0315 or approval of instructor.', 'Course Lecture Hours (l)': 3, 'Course Name': 'Software Development, Globalization and Culture Abroad'}
# CSCE 430 => {'Course Other Hours (l)': -1, 'Course Credit Hours (l)': 3, 'Course Lab Hours (u)': 3, 'Course Credit Hours (u)': 3, 'Course Other Hours (u)': -1, 'Course Description': 'Methods for analyzing fundamental programming problems from a variety of domains and implementing solutions quickly and efficiently; problems based on competitive programming contests to develop skills in problem analysis, coding and testing; solving problems will involve identifying and applying a range of algorithmic solutions; includes dealing with combinatorics, dynamic programming, graphs, numerical calculations, string processing and geometry, along with other specialized algorithms. Prerequisites: CSCE\xa0411 or approval of instructor.', 'Course Name': 'Problem Solving Programming Strategies', 'Course Lecture Hours (l)': 2, 'Course Lecture Hours (u)': 2, 'Course Lab Hours (l)': 3}
# CSCE 431 => {'Course Lab Hours (u)': 2, 'Course Other Hours (u)': -1, 'Course Description': 'Application of engineering approach to computer software design and development; life cycle models, software requirements and specification; conceptual model design; detailed design; validation and verification; design quality assurance; software design/development environments and project management. Prerequisite: CSCE\xa0315 or approval of instructor.', 'Course Lecture Hours (l)': 2, 'Course Name': 'Software Engineering', 'Course Credit Hours (l)': 3, 'Course Lab Hours (l)': 2, 'Course Lecture Hours (u)': 2, 'Course Credit Hours (u)': 3, 'Course Other Hours (l)': -1}
# CSCE 433 => {'Course Other Hours (l)': -1, 'Course Lab Hours (u)': -1, 'Course Credit Hours (u)': 3, 'Course Name': 'Formal Languages and Automata', 'Course Lecture Hours (u)': 3, 'Course Credit Hours (l)': 3, 'Course Description': 'Basic types of abstract languages and their acceptors; the Chomsky hierarchy; solvability and recursive function theory; application of theoretical results to practical problems. Prerequisite: CSCE\xa0315 or approval of instructor.', 'Course Other Hours (u)': -1, 'Course Lecture Hours (l)': 3, 'Course Lab Hours (l)': -1}
# CSCE 434 => {'Course Other Hours (l)': -1, 'Course Lab Hours (u)': -1, 'Course Description': 'Programming language translation; functions and general organization of compiler design and interpreters; theoretical and implementation aspects of lexical scanners; parsing of context free languages; code generation and optimization; error recovery. Prerequisite: CSCE\xa0315 or approval of instructor.', 'Course Name': 'Compiler Design', 'Course Credit Hours (u)': 3, 'Course Lecture Hours (u)': 3, 'Course Credit Hours (l)': 3, 'Course Other Hours (u)': -1, 'Course Lab Hours (l)': -1, 'Course Lecture Hours (l)': 3}
# CSCE 435 => {'Course Lab Hours (u)': -1, 'Course Other Hours (u)': -1, 'Course Description': 'Overview of parallel computing technology and programming methods; includes multiprocessor architectures, programming tools, parallel performance, parallel algorithms, and applications of parallel computing. Prerequisites: CSCE\xa0315 and junior or senior classification; or approval of instructor.', 'Course Name': 'Parallel Computing', 'Course Credit Hours (l)': 3, 'Course Lecture Hours (l)': 3, 'Course Lecture Hours (u)': 3, 'Course Lab Hours (l)': -1, 'Course Credit Hours (u)': 3, 'Course Other Hours (l)': -1}
# CSCE 436 => {'Course Other Hours (l)': -1, 'Course Lab Hours (u)': -1, 'Course Credit Hours (u)': 3, 'Course Name': 'Computer-Human Interaction', 'Course Credit Hours (l)': 3, 'Course Lecture Hours (u)': 3, 'Course Description': 'Comprehensive study of the Computer-Human Interaction (CHI) area; includes history and importance of CHI; CHI design theories; modeling of computer users and interfaces; empirical techniques for task analysis and interface design; styles of interaction and future directions of CHI including hypermedia and computer-supported collaborative work. Prerequisite: CSCE\xa0315 or concurrent enrollment or approval of instructor.', 'Course Other Hours (u)': -1, 'Course Lecture Hours (l)': 3, 'Course Lab Hours (l)': -1}
# CSCE 438 => {'Course Lab Hours (u)': -1, 'Course Other Hours (u)': -1, 'Course Description': 'Principles and techniques for engineering distributed systems with topics including communication, concurrency, programming paradigms, naming, managing shared state, caching, synchronization, reaching agreement, fault tolerance, security, middleware and distributed applications; design, implement and debug large software systems. Prerequisite: CSCE\xa0313; junior or senior classification, or approval of instructor.', 'Course Lecture Hours (l)': 3, 'Course Credit Hours (l)': 3, 'Course Name': 'Distributed Systems', 'Course Lab Hours (l)': -1, 'Course Lecture Hours (u)': 3, 'Course Credit Hours (u)': 3, 'Course Other Hours (l)': -1}
# CSCE 440 => {'Course Description': 'Introduction to the design and analysis of quantum algorithms; basic principles of the quantum circuit model; gives a gentle introduction to basic quantum algorithms; reviews recent results in quantum information processing. Prerequisite: CSCE\xa0315 or approval of instructor.', 'Course Lab Hours (l)': -1, 'Course Other Hours (l)': -1, 'Course Lecture Hours (l)': 3, 'Course Lab Hours (u)': -1, 'Course Name': 'Quantum Algorithms', 'Course Lecture Hours (u)': 3, 'Course Credit Hours (u)': 3, 'Course Credit Hours (l)': 3, 'Course Other Hours (u)': -1}
# CSCE 441 => {'Course Lab Hours (l)': -1, 'Course Name': 'Computer Graphics', 'Course Lecture Hours (u)': 3, 'Course Credit Hours (l)': 3, 'Course Credit Hours (u)': 3, 'Course Description': 'Principles of interactive computer graphics; 2-D and 3-D rendering pipelines, including geometric object and view transformations, projections, hidden surface removal, and rasterization; lighting models for local and global illumination; hierarchical models of 3-D objects; systems and libraries supporting display and user interaction. Prerequisite: CSCE\xa0221; junior or senior classification or approval of instructor.', 'Course Other Hours (l)': -1, 'Course Lecture Hours (l)': 3, 'Course Lab Hours (u)': -1, 'Course Other Hours (u)': -1}
# CSCE 442 => {'Course Other Hours (l)': -1, 'Course Lab Hours (u)': -1, 'Course Description': 'Introduction to numerical algorithms fundamental to scientific and engineering applications of computers; elementary discussion of error; algorithms, efficiency; polynomial approximations, quadrature and systems of algebraic and differential equations. Prerequisites: CSCE\xa0221 with a grade of C or better; MATH\xa0304 or MATH\xa0308 or concurrent enrollment.', 'Course Name': 'Scientific Programming', 'Course Lecture Hours (u)': 3, 'Course Credit Hours (u)': 3, 'Course Credit Hours (l)': 3, 'Course Other Hours (u)': -1, 'Course Lecture Hours (l)': 3, 'Course Lab Hours (l)': -1}
# CSCE 443 => {'Course Lab Hours (u)': 2, 'Course Other Hours (l)': -1, 'Course Credit Hours (u)': 3, 'Course Name': 'Game Development', 'Course Lecture Hours (u)': 2, 'Course Credit Hours (l)': 3, 'Course Description': 'Aesthetic and technical aspects of computer game development, including game mechanics, story development, content creation and game programming; includes game design, interface design, 3D modeling and animation, graphics algorithms, shader programming and artificial intelligence; group project includes the design and development of a game from start to finish. Prerequisites: CSCE\xa0441 or VIST\xa0486 or approval of instructor; junior or senior classification. Cross Listing: VIST\xa0487/CSCE\xa0443.', 'Course Other Hours (u)': -1, 'Course Lecture Hours (l)': 2, 'Course Lab Hours (l)': 2}
# CSCE 444 => {'Course Lecture Hours (u)': 2, 'Course Other Hours (u)': -1, 'Course Other Hours (l)': -1, 'Course Description': 'A systems approach to the programming, design, authoring and theory of hypermedia; object-oriented visual and interactive programming; visual design, including color, space, text and layering; the reference as a metadisciplinary structure; collecting and sampling; ontologies, maps and navigation as means of structuring information; create dynamic hypermedia that is expressive and interpretive. Prerequisite: CSCE\xa0315 or approval of instructor.', 'Course Lecture Hours (l)': 2, 'Course Lab Hours (l)': 2, 'Course Lab Hours (u)': 2, 'Course Credit Hours (l)': 3, 'Course Credit Hours (u)': 3, 'Course Name': 'Structures of Interactive Information'}
# CSCE 445 => {'Course Lab Hours (u)': -1, 'Course Other Hours (u)': -1, 'Course Description': 'Potential and realized impact of computers in the design of new media; relationship between authors and readers of interactive material; influence of media design on the content expressed. Prerequisite: CSCE\xa0221 or approval of instructor.', 'Course Lecture Hours (l)': 3, 'Course Credit Hours (l)': 3, 'Course Name': 'Computers and New Media', 'Course Lecture Hours (u)': 3, 'Course Lab Hours (l)': -1, 'Course Credit Hours (u)': 3, 'Course Other Hours (l)': -1}
# CSCE 446 => {'Course Other Hours (l)': -1, 'Course Lab Hours (u)': -1, 'Course Credit Hours (u)': 3, 'Course Name': 'Virtual Reality', 'Course Credit Hours (l)': 3, 'Course Lecture Hours (u)': 3, 'Course Description': 'Theory and practice of virtual reality; interactive 3D virtual environments; input/output devices, 3D interaction techniques, augmented reality, role of realism in VR, navigation techniques, design guidelines and evaluation methods. Prerequisite: Grade of C or better in VIST\xa0271, CSCE\xa0221, or CSCE\xa0441. Cross Listing: VIST\xa0477/CSCE\xa0446.', 'Course Other Hours (u)': -1, 'Course Lab Hours (l)': -1, 'Course Lecture Hours (l)': 3}
# CSCE 447 => {'Course Lecture Hours (u)': 3, 'Course Other Hours (u)': -1, 'Course Other Hours (l)': -1, 'Course Description': 'Visual representation and design of data and information; 3D visualization, infographics, data narratives, principles of visual data encoding and interaction techniques. Prerequisite: Grade of C or better in VIST\xa0271, or CSCE\xa0221, or CSCE\xa0441. Cross Listing: VIST\xa0476/CSCE\xa0447.', 'Course Lecture Hours (l)': 3, 'Course Lab Hours (l)': -1, 'Course Credit Hours (l)': 3, 'Course Lab Hours (u)': -1, 'Course Credit Hours (u)': 3, 'Course Name': 'Data Visualization'}
# CSCE 449 => {'Course Other Hours (l)': -1, 'Course Lab Hours (u)': -1, 'Course Description': 'Applied cryptography; secure multi-party computations; zero knowledge proofs; blockchain and machine learning. Prerequisite: CSCE\xa0221.', 'Course Name': 'Applied Cryptography', 'Course Credit Hours (u)': 3, 'Course Other Hours (u)': -1, 'Course Lecture Hours (u)': 3, 'Course Credit Hours (l)': 3, 'Course Lab Hours (l)': -1, 'Course Lecture Hours (l)': 3}
# CSCE 451 => {'Course Other Hours (l)': -1, 'Course Lab Hours (u)': 2, 'Course Credit Hours (u)': 3, 'Course Name': 'Software Reverse Engineering', 'Course Credit Hours (l)': 3, 'Course Lecture Hours (u)': 2, 'Course Description': 'Overview of the compilation mechanism to generate executable files and raw binary codes from source codes; executable file formats for an operating system to run the binary code; disassembly algorithms and control graph analysis; static and dynamic analyses; case studies on code obfuscation, codebreaking, malware analysis. Prerequisite: CSCE\xa0313 or approval of instructor.', 'Course Other Hours (u)': -1, 'Course Lecture Hours (l)': 2, 'Course Lab Hours (l)': 2}
# CSCE 452 => {'Course Lecture Hours (u)': 3, 'Course Other Hours (u)': -1, 'Course Other Hours (l)': -1, 'Course Lecture Hours (l)': 3, 'Course Description': 'Algorithms for executing spatial tasks; path planning and obstacle aance in two- and three-dimensional robots--configuration space, potential field, free-space decomposition methods; stable grasping and manipulation; dealing with uncertainty; knowledge representation for planning--geometric and symbolic models of the environment; task-level programming; learning. Prerequisite: CSCE\xa0315 or approval of instructor.', 'Course Lab Hours (l)': -1, 'Course Lab Hours (u)': -1, 'Course Credit Hours (l)': 3, 'Course Credit Hours (u)': 3, 'Course Name': 'Robotics and Spatial Intelligence'}
# CSCE 456 => {'Course Other Hours (l)': -1, 'Course Lab Hours (u)': 3, 'Course Name': 'Real-Time Computing', 'Course Description': 'Introduction to principles and applications of real-time computing; system architecture; D/A and A/D conversion; synchronous data acquisition and analysis; computers in real-time control; asynchronous monitoring and control; resource scheduling; interfacing issues; lectures and laboratory. Prerequisites: CSCE\xa0313 and MATH\xa0152.', 'Course Credit Hours (u)': 4, 'Course Lecture Hours (u)': 3, 'Course Credit Hours (l)': 4, 'Course Other Hours (u)': -1, 'Course Lab Hours (l)': 3, 'Course Lecture Hours (l)': 3}
# CSCE 461 => {'Course Lecture Hours (u)': 2, 'Course Other Hours (u)': -1, 'Course Other Hours (l)': -1, 'Course Description': 'Principles of embedded system architecture and programming; fundamentals and theoretical foundations of wireless communication systems; hands-on experiences of how an embedded system could be used to solve problems in biomedical engineering; projects on wireless sensors and imaging for medical devices. Prerequisite: BMEN\xa0211, CSCE\xa0350/ECEN\xa0350, or CSCE\xa0315, or approval of instructor. Cross Listing: BMEN\xa0428/CSCE\xa0461.', 'Course Lecture Hours (l)': 2, 'Course Lab Hours (l)': 3, 'Course Lab Hours (u)': 3, 'Course Credit Hours (l)': 3, 'Course Credit Hours (u)': 3, 'Course Name': 'Embedded Systems for Medical Applications'}
# CSCE 462 => {'Course Other Hours (l)': -1, 'Course Lab Hours (u)': 1, 'Course Credit Hours (u)': 3, 'Course Name': 'Microcomputer Systems', 'Course Credit Hours (l)': 3, 'Course Lecture Hours (u)': 2, 'Course Description': 'Microcomputers as components of systems; VLSI processor and coprocessor architectures, addressing and instruction sets; I/O interfaces and supervisory control; VLSI architectures for signal processing; integrating special purpose processors into a system. Prerequisite: CSCE\xa0313.', 'Course Other Hours (u)': -1, 'Course Lecture Hours (l)': 2, 'Course Lab Hours (l)': 1}
# CSCE 463 => {'Course Description': 'Basic hardware/software, architectural components for computer communications; computer networks, switching, routing, protocols and security; multiprocessing and distributed processing; interfacing operating systems and networks; case studies of existing networks and network architectures. Prerequisite: CSCE\xa0313 or approval of instructor.', 'Course Lab Hours (l)': -1, 'Course Other Hours (l)': -1, 'Course Lecture Hours (l)': 3, 'Course Lab Hours (u)': -1, 'Course Name': 'Networks and Distributed Processing', 'Course Lecture Hours (u)': 3, 'Course Credit Hours (u)': 3, 'Course Credit Hours (l)': 3, 'Course Other Hours (u)': -1}
# CSCE 464 => {'Course Other Hours (l)': -1, 'Course Lab Hours (u)': -1, 'Course Credit Hours (l)': 3, 'Course Credit Hours (u)': 3, 'Course Description': 'Introduction to wireless and mobile systems; wireless communication fundamentals; wireless medium access control design; transmission scheduling, network and transport protocols over wireless design, simulation and evaluation; wireless capacity; telecommunication systems; vehicular, adhoc, and sensor network systems; wireless security; mobile applications. Prerequisites: CSCE\xa0313; junior or senior classification or approval of instructor.', 'Course Other Hours (u)': -1, 'Course Lecture Hours (l)': 3, 'Course Name': 'Wireless and Mobile Systems', 'Course Lab Hours (l)': -1, 'Course Lecture Hours (u)': 3}
# CSCE 465 => {'Course Lab Hours (l)': -1, 'Course Name': 'Computer and Network Security', 'Course Lecture Hours (u)': 3, 'Course Credit Hours (l)': 3, 'Course Credit Hours (u)': 3, 'Course Description': 'Fundamental concepts and principles of computer security, operating system and network security, secret key and public key cryptographic algorithms, hash functions, authentication, firewalls and intrusion detection systems, IPSec and VPN, wireless and web security. Prerequisites: CSCE\xa0313 and CSCE\xa0315; junior or senior classification; or approval of instructor.', 'Course Lecture Hours (l)': 3, 'Course Other Hours (l)': -1, 'Course Lab Hours (u)': -1, 'Course Other Hours (u)': -1}
# CSCE 469 => {'Course Other Hours (l)': -1, 'Course Lab Hours (u)': -1, 'Course Description': 'Advanced computer architectures including memory designs, pipeline techniques, and parallel structures such as vector computers and multiprocessors. Prerequisite: Grade of C or better in ECEN\xa0350/CSCE\xa0350 or CSCE\xa0350/ECEN\xa0350; junior or senior classification. Cross Listing: ECEN\xa0469/CSCE\xa0469.', 'Course Name': 'Advanced Computer Architecture', 'Course Other Hours (u)': -1, 'Course Credit Hours (u)': 3, 'Course Lecture Hours (u)': 3, 'Course Credit Hours (l)': 3, 'Course Lecture Hours (l)': 3, 'Course Lab Hours (l)': -1}
# CSCE 470 => {'Course Lab Hours (l)': -1, 'Course Name': 'Information Storage and Retrieval', 'Course Lecture Hours (u)': 3, 'Course Credit Hours (l)': 3, 'Course Credit Hours (u)': 3, 'Course Description': 'Representation of, storage of and access to very large multimedia document collections; fundamental data structures and algorithms of current information storage and retrieval systems and relates various techniques to design and evaluation of complete retrieval systems. Prerequisite: CSCE\xa0315 or approval of instructor.', 'Course Lecture Hours (l)': 3, 'Course Other Hours (l)': -1, 'Course Lab Hours (u)': -1, 'Course Other Hours (u)': -1}
# CSCE 477 => {'Course Description': 'Risks in cybersecurity; avoidance, acceptance, mitigation, or transference strategies; developing reliable cybersecurity risk assessments to include analysis, categorization, and evaluation; cybersecurity risk audit frameworks. Prerequisite: Grade of C or better in CYBR\xa0201/CSCE\xa0201, CSCE\xa0201/CYBR\xa0201, or CSCE\xa0221; junior or senior classification. Cross Listing: CYBR\xa0403/CSCE\xa0477.', 'Course Name': 'Cybersecurity Risk', 'Course Credit Hours (u)': 3, 'Course Lecture Hours (l)': 3, 'Course Other Hours (u)': -1, 'Course Lecture Hours (u)': 3, 'Course Lab Hours (l)': -1, 'Course Other Hours (l)': -1, 'Course Lab Hours (u)': -1, 'Course Credit Hours (l)': 3}
# CSCE 481 => {'Course Description': 'Investigation and report by students on topics of current interest in computer science. Prerequisite: Junior or senior classification.', 'Course Lab Hours (l)': 2, 'Course Other Hours (l)': -1, 'Course Lecture Hours (l)': -1, 'Course Lab Hours (u)': 2, 'Course Name': 'Seminar', 'Course Lecture Hours (u)': -1, 'Course Credit Hours (u)': 1, 'Course Credit Hours (l)': 1, 'Course Other Hours (u)': -1}
# CSCE 482 => {'Course Lab Hours (u)': 6, 'Course Other Hours (u)': -1, 'Course Description': 'Project-based course to develop system integration skills for solving real-world problems in computer science; significant team software project that integrates advanced concepts across computer science specializations; projects require design, implementation, documentation and demonstration, as well as design methodology, management process and teamwork. Prerequisites: Senior classification; CSCE\xa0315, CSCE\xa0411, and two additional CSCE tracked courses.', 'Course Lecture Hours (l)': 1, 'Course Credit Hours (l)': 3, 'Course Name': 'Senior Capstone Design', 'Course Lecture Hours (u)': 1, 'Course Lab Hours (l)': 6, 'Course Credit Hours (u)': 3, 'Course Other Hours (l)': -1}
# CSCE 483 => {'Course Description': "Engineering design; working as a design-team member, conceptual design methodology, design evaluations, total project planning and management techniques, design optimization, systems manufacturing costs considerations; emphasis placed upon students' activities as design professionals. Prerequisites: CSCE\xa0315, CSCE\xa0462 and ECEN\xa0325; senior classification.", 'Course Lab Hours (l)': 6, 'Course Other Hours (l)': -1, 'Course Lecture Hours (l)': 1, 'Course Lab Hours (u)': 6, 'Course Name': 'Computer Systems Design', 'Course Lecture Hours (u)': 1, 'Course Credit Hours (u)': 3, 'Course Credit Hours (l)': 3, 'Course Other Hours (u)': -1}
# CSCE 485 => {'Course Other Hours (l)': 0, 'Course Lab Hours (u)': -1, 'Course Description': 'Permits work on special project in computer science; project must be approved by the department. Prerequisite: Senior classification; also taught at Galveston campus.', 'Course Name': 'Directed Studies', 'Course Credit Hours (l)': 0, 'Course Other Hours (u)': 6, 'Course Credit Hours (u)': 6, 'Course Lecture Hours (u)': -1, 'Course Lecture Hours (l)': -1, 'Course Lab Hours (l)': -1}
# CSCE 489 => {'Course Other Hours (u)': 4, 'Course Lecture Hours (u)': -1, 'Course Credit Hours (l)': 1, 'Course Credit Hours (u)': 4, 'Course Lab Hours (l)': -1, 'Course Other Hours (l)': 1, 'Course Lab Hours (u)': -1, 'Course Description': 'Special topics in computer science that are new or unique that are not covered in existing courses.', 'Course Lecture Hours (l)': -1, 'Course Name': 'Special Topics in...'}
# CSCE 491 => {'Course Lab Hours (u)': -1, 'Course Other Hours (u)': 4, 'Course Description': 'Research conducted under the direction of faculty member in computer science. May be taken three times for credit. Prerequisites: Junior or senior classification and approval of instructor.', 'Course Credit Hours (l)': 0, 'Course Name': 'Research', 'Course Lecture Hours (l)': -1, 'Course Lecture Hours (u)': -1, 'Course Lab Hours (l)': -1, 'Course Credit Hours (u)': 4, 'Course Other Hours (l)': 0}
