# %%
# installing firebase library
# !pip install --upgrade firebase-admin

# %%
# Loading necessary libraries
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore
import pandas as pd

# %%
# Initialize firebase instance with credentials
cred = credentials.Certificate("/content/drive/Shareddrives/CSCE 634/Software/Database/hotspot-bab51-firebase-adminsdk-yo4gy-8a69f79409.json")
firebase_admin.initialize_app(cred)

db = firestore.client()

# Read data
courses_ref = db.collection(u'Courses')
docs = courses_ref.stream()
for doc in docs:
    print(f'{doc.id} => {doc.to_dict()}')
# Out:
# CSCE 110 => {'Course Lecture Hours (l)': 3, 'Course Lab Hours (u)': 2, 'Course Credit Hours (l)': 4, 'Course Other Hours (l)': -1, 'Course Other Hours (u)': -1, 'Course Name': 'Programming I', 'Course Description': 'Basic concepts in using computation to enhance problem solving abilities; understanding how people communicate with computers, and how computing affects society; computational thinking; representation of data; analysis of program behavior; methods for identifying and fixing errors in programs; understanding abilities and limitation of programs; development and execution of programs.', 'Course Lab Hours (l)': 2, 'Course Lecture Hours (u)': 3, 'Course Credit Hours (u)': 4}
# ...
